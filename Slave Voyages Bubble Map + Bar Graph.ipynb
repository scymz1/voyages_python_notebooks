# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
import plotly.express as px
import numpy as np
import json
import re
from app_secrets import *

import requests
base_url='https://voyages3-api.crc.rice.edu/voyage/'

# %%
"""
These arrays provide the variety of variables which can be used for the construction of the data visualizations.
Numeric_vars referred to the actual value we are trying to retrieve, geo_vars refer to variables indicating location
and the date_vars provide time references against which the data would be queried. 
"""


numeric_vars = ['voyage_slaves_numbers__imp_total_num_slaves_disembarked',
                'voyage_slaves_numbers__imp_total_num_slaves_embarked']

geo_vars = ['voyage_itinerary__imp_principal_place_of_slave_purchase__place',
           'voyage_itinerary__imp_principal_port_slave_dis__place',
           'voyage_itinerary__imp_principal_region_slave_dis__region',
           'voyage_itinerary__imp_principal_region_of_slave_purchase__region']

date_vars = ['voyage_dates__arrival_at_second_place_landing_yyyy',
            'voyage_dates__date_departed_africa_yyyy',
            'voyage_dates__departure_last_place_of_landing_yyyy',
            'voyage_dates__first_dis_of_slaves_yyyy',
            'voyage_dates__imp_arrival_at_port_of_dis_yyyy',
            'voyage_dates__imp_departed_africa_yyyy',
            'voyage_dates__imp_voyage_began_yyyy',
            'voyage_dates__slave_purchase_began_yyyy',
            'voyage_dates__third_dis_of_slaves_yyyy',
            'voyage_dates__vessel_left_port_yyyy',
            'voyage_dates__voyage_began_yyyy',
            'voyage_dates__voyage_completed_yyyy']

r = requests.options(base_url + '?hierarchical=False', headers=headers) # to get the specific label names of above vars
drop_dict = r.json()

# %%
drop_dict
# Out:
# {'id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'ID'},
#  'voyage_itinerary': {'type': 'table',
#   'label': 'Itinerary',
#   'flatlabel': 'Itinerary'},
#  'voyage_itinerary__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : ID'},
#  'voyage_itinerary__port_of_departure': {'type': 'table',
#   'label': 'Port of departure (PORTDEP)',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP)'},
#  'voyage_itinerary__port_of_departure__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : ID'},
#  'voyage_itinerary__port_of_departure__region': {'type': 'table',
#   'label': 'Region',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region'},
#  'voyage_itinerary__port_of_departure__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : ID'},
#  'voyage_itinerary__port_of_departure__region__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region'},
#  'voyage_itinerary__port_of_departure__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : ID'},
#  'voyage_itinerary__port_of_departure__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__port_of_departure__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : Longitude of point'},
#  'voyage_itinerary__port_of_departure__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : Latitude of point'},
#  'voyage_itinerary__port_of_departure__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : Numeric code'},
#  'voyage_itinerary__port_of_departure__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Broad Region : Show on map'},
#  'voyage_itinerary__port_of_departure__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Specific region (country or colony)'},
#  'voyage_itinerary__port_of_departure__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Longitude of point'},
#  'voyage_itinerary__port_of_departure__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Latitude of point'},
#  'voyage_itinerary__port_of_departure__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Numeric code'},
#  'voyage_itinerary__port_of_departure__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Show on map'},
#  'voyage_itinerary__port_of_departure__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Region : Show on main map'},
#  'voyage_itinerary__port_of_departure__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Place',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Place'},
#  'voyage_itinerary__port_of_departure__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Numeric code'},
#  'voyage_itinerary__port_of_departure__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Longitude of point'},
#  'voyage_itinerary__port_of_departure__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Latitude of point'},
#  'voyage_itinerary__port_of_departure__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Show on main map'},
#  'voyage_itinerary__port_of_departure__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map',
#   'flatlabel': 'Itinerary : Port of departure (PORTDEP) : Show on voyage map'},
#  'voyage_itinerary__int_first_port_emb': {'type': 'table',
#   'label': 'First intended port of embarkation (EMBPORT)',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT)'},
#  'voyage_itinerary__int_first_port_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : ID'},
#  'voyage_itinerary__int_first_port_emb__region': {'type': 'table',
#   'label': 'Region',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region'},
#  'voyage_itinerary__int_first_port_emb__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : ID'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : ID'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : Numeric code'},
#  'voyage_itinerary__int_first_port_emb__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Broad Region : Show on map'},
#  'voyage_itinerary__int_first_port_emb__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Specific region (country or colony)'},
#  'voyage_itinerary__int_first_port_emb__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Longitude of point'},
#  'voyage_itinerary__int_first_port_emb__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Latitude of point'},
#  'voyage_itinerary__int_first_port_emb__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Numeric code'},
#  'voyage_itinerary__int_first_port_emb__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Show on map'},
#  'voyage_itinerary__int_first_port_emb__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Region : Show on main map'},
#  'voyage_itinerary__int_first_port_emb__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Place',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Place'},
#  'voyage_itinerary__int_first_port_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Numeric code'},
#  'voyage_itinerary__int_first_port_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Longitude of point'},
#  'voyage_itinerary__int_first_port_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Latitude of point'},
#  'voyage_itinerary__int_first_port_emb__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Show on main map'},
#  'voyage_itinerary__int_first_port_emb__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map',
#   'flatlabel': 'Itinerary : First intended port of embarkation (EMBPORT) : Show on voyage map'},
#  'voyage_itinerary__int_second_port_emb': {'type': 'table',
#   'label': 'Second intended port of embarkation (EMBPORT2)',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2)'},
#  'voyage_itinerary__int_second_port_emb__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : ID'},
#  'voyage_itinerary__int_second_port_emb__region': {'type': 'table',
#   'label': 'Region',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region'},
#  'voyage_itinerary__int_second_port_emb__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : ID'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : ID'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : Numeric code'},
#  'voyage_itinerary__int_second_port_emb__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Broad Region : Show on map'},
#  'voyage_itinerary__int_second_port_emb__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Specific region (country or colony)'},
#  'voyage_itinerary__int_second_port_emb__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Longitude of point'},
#  'voyage_itinerary__int_second_port_emb__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Latitude of point'},
#  'voyage_itinerary__int_second_port_emb__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Numeric code'},
#  'voyage_itinerary__int_second_port_emb__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Show on map'},
#  'voyage_itinerary__int_second_port_emb__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Region : Show on main map'},
#  'voyage_itinerary__int_second_port_emb__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Place',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Place'},
#  'voyage_itinerary__int_second_port_emb__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Numeric code'},
#  'voyage_itinerary__int_second_port_emb__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Longitude of point'},
#  'voyage_itinerary__int_second_port_emb__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Latitude of point'},
#  'voyage_itinerary__int_second_port_emb__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Show on main map'},
#  'voyage_itinerary__int_second_port_emb__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map',
#   'flatlabel': 'Itinerary : Second intended port of embarkation (EMBPORT2) : Show on voyage map'},
#  'voyage_itinerary__int_first_region_purchase_slaves': {'type': 'table',
#   'label': 'First intended region of purchase of slaves (EMBREG)',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG)'},
#  'voyage_itinerary__int_first_region_purchase_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : ID'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : ID'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : Numeric code'},
#  'voyage_itinerary__int_first_region_purchase_slaves__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Broad Region : Show on map'},
#  'voyage_itinerary__int_first_region_purchase_slaves__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Specific region (country or colony)'},
#  'voyage_itinerary__int_first_region_purchase_slaves__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Longitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Latitude of point'},
#  'voyage_itinerary__int_first_region_purchase_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Numeric code'},
#  'voyage_itinerary__int_first_region_purchase_slaves__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Show on map'},
#  'voyage_itinerary__int_first_region_purchase_slaves__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended region of purchase of slaves (EMBREG) : Show on main map'},
#  'voyage_itinerary__int_second_region_purchase_slaves': {'type': 'table',
#   'label': 'Second intended region of purchase of slaves (EMBREG2)',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2)'},
#  'voyage_itinerary__int_second_region_purchase_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : ID'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : ID'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : Numeric code'},
#  'voyage_itinerary__int_second_region_purchase_slaves__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Broad Region : Show on map'},
#  'voyage_itinerary__int_second_region_purchase_slaves__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Specific region (country or colony)'},
#  'voyage_itinerary__int_second_region_purchase_slaves__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Longitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Latitude of point'},
#  'voyage_itinerary__int_second_region_purchase_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Numeric code'},
#  'voyage_itinerary__int_second_region_purchase_slaves__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Show on map'},
#  'voyage_itinerary__int_second_region_purchase_slaves__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended region of purchase of slaves (EMBREG2) : Show on main map'},
#  'voyage_itinerary__int_first_port_dis': {'type': 'table',
#   'label': 'First intended port of disembarkation (ARRPORT)',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT)'},
#  'voyage_itinerary__int_first_port_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : ID'},
#  'voyage_itinerary__int_first_port_dis__region': {'type': 'table',
#   'label': 'Region',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region'},
#  'voyage_itinerary__int_first_port_dis__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : ID'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : ID'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : Numeric code'},
#  'voyage_itinerary__int_first_port_dis__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Broad Region : Show on map'},
#  'voyage_itinerary__int_first_port_dis__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Specific region (country or colony)'},
#  'voyage_itinerary__int_first_port_dis__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Longitude of point'},
#  'voyage_itinerary__int_first_port_dis__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Latitude of point'},
#  'voyage_itinerary__int_first_port_dis__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Numeric code'},
#  'voyage_itinerary__int_first_port_dis__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Show on map'},
#  'voyage_itinerary__int_first_port_dis__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Region : Show on main map'},
#  'voyage_itinerary__int_first_port_dis__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Place',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Place'},
#  'voyage_itinerary__int_first_port_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Numeric code'},
#  'voyage_itinerary__int_first_port_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Longitude of point'},
#  'voyage_itinerary__int_first_port_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Latitude of point'},
#  'voyage_itinerary__int_first_port_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Show on main map'},
#  'voyage_itinerary__int_first_port_dis__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map',
#   'flatlabel': 'Itinerary : First intended port of disembarkation (ARRPORT) : Show on voyage map'},
#  'voyage_itinerary__int_second_port_dis': {'type': 'table',
#   'label': 'Second intended port of disembarkation (ARRPORT2)',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2)'},
#  'voyage_itinerary__int_second_port_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : ID'},
#  'voyage_itinerary__int_second_port_dis__region': {'type': 'table',
#   'label': 'Region',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region'},
#  'voyage_itinerary__int_second_port_dis__region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : ID'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : ID'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : Numeric code'},
#  'voyage_itinerary__int_second_port_dis__region__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Broad Region : Show on map'},
#  'voyage_itinerary__int_second_port_dis__region__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Specific region (country or colony)'},
#  'voyage_itinerary__int_second_port_dis__region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Longitude of point'},
#  'voyage_itinerary__int_second_port_dis__region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Latitude of point'},
#  'voyage_itinerary__int_second_port_dis__region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Numeric code'},
#  'voyage_itinerary__int_second_port_dis__region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Show on map'},
#  'voyage_itinerary__int_second_port_dis__region__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Region : Show on main map'},
#  'voyage_itinerary__int_second_port_dis__place': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Place',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Place'},
#  'voyage_itinerary__int_second_port_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Numeric code'},
#  'voyage_itinerary__int_second_port_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Longitude of point'},
#  'voyage_itinerary__int_second_port_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Latitude of point'},
#  'voyage_itinerary__int_second_port_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Show on main map'},
#  'voyage_itinerary__int_second_port_dis__show_on_voyage_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on voyage map',
#   'flatlabel': 'Itinerary : Second intended port of disembarkation (ARRPORT2) : Show on voyage map'},
#  'voyage_itinerary__int_first_region_slave_landing': {'type': 'table',
#   'label': 'First intended region of slave landing (REGARR)',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR)'},
#  'voyage_itinerary__int_first_region_slave_landing__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : ID'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : ID'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : Numeric code'},
#  'voyage_itinerary__int_first_region_slave_landing__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Broad Region : Show on map'},
#  'voyage_itinerary__int_first_region_slave_landing__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Specific region (country or colony)'},
#  'voyage_itinerary__int_first_region_slave_landing__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Longitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Latitude of point'},
#  'voyage_itinerary__int_first_region_slave_landing__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Numeric code'},
#  'voyage_itinerary__int_first_region_slave_landing__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Show on map'},
#  'voyage_itinerary__int_first_region_slave_landing__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : First intended region of slave landing (REGARR) : Show on main map'},
#  'voyage_itinerary__imp_principal_region_slave_dis': {'type': 'table',
#   'label': 'Imputed principal region of slave disembarkation (MJSELIMP)',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP)'},
#  'voyage_itinerary__imp_principal_region_slave_dis__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : ID'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : ID'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : Longitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : Latitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : Numeric code'},
#  'voyage_itinerary__imp_principal_region_slave_dis__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Broad Region : Show on map'},
#  'voyage_itinerary__imp_principal_region_slave_dis__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Specific region (country or colony)'},
#  'voyage_itinerary__imp_principal_region_slave_dis__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Longitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Latitude of point'},
#  'voyage_itinerary__imp_principal_region_slave_dis__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Numeric code'},
#  'voyage_itinerary__imp_principal_region_slave_dis__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Show on map'},
#  'voyage_itinerary__imp_principal_region_slave_dis__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Imputed principal region of slave disembarkation (MJSELIMP) : Show on main map'},
#  'voyage_itinerary__int_second_place_region_slave_landing': {'type': 'table',
#   'label': 'Second intended region of slave landing (REGARR2)',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2)'},
#  'voyage_itinerary__int_second_place_region_slave_landing__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : ID'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region': {'type': 'table',
#   'label': 'Broad Region',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : ID'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__broad_region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Broad region (Area) name',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : Broad region (Area) name'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : Longitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : Latitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : Numeric code'},
#  'voyage_itinerary__int_second_place_region_slave_landing__broad_region__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Broad Region : Show on map'},
#  'voyage_itinerary__int_second_place_region_slave_landing__region': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Specific region (country or colony)',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Specific region (country or colony)'},
#  'voyage_itinerary__int_second_place_region_slave_landing__longitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Longitude of point',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Longitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__latitude': {'type': "<class 'rest_framework.fields.DecimalField'>",
#   'label': 'Latitude of point',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Latitude of point'},
#  'voyage_itinerary__int_second_place_region_slave_landing__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Numeric code',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Numeric code'},
#  'voyage_itinerary__int_second_place_region_slave_landing__show_on_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on map',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Show on map'},
#  'voyage_itinerary__int_second_place_region_slave_landing__show_on_main_map': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Show on main map',
#   'flatlabel': 'Itinerary : Second intended region of slave landing (REGARR2) : Show on main map'},
#  'voyage_itinerary__first_place_slave_purchase': {'type': 'table',
#   'label': 'First place of slave purchase (PLAC1TRA)',
#   'flatlabel': 'Itinerary : First place of slave purchase (PLAC1TRA)'},
#  'voyage_itinerary__first_place_slave_purchase__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
# ...
#   'flatlabel': 'voyage slaves numbers : Imputed number of females landed (FEML3IMP)'},
#  'voyage_slaves_numbers__total_slaves_landed_age_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age among landed slaves (SLAVEMA3)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by age among landed slaves (SLAVEMA3)'},
#  'voyage_slaves_numbers__total_slaves_landed_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by gender among landed slaves (SLAVEMX3)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by gender among landed slaves (SLAVEMX3)'},
#  'voyage_slaves_numbers__total_slaves_dept_or_arr_age_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age at departure or arrival (SLAVEMA7)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by age at departure or arrival (SLAVEMA7)'},
#  'voyage_slaves_numbers__total_slaves_dept_or_arr_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by gender at departure or arrival(SLAVEMX7)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by gender at departure or arrival(SLAVEMX7)'},
#  'voyage_slaves_numbers__imp_slaves_embarked_for_mortality': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Imputed number of slaves embarked for mortality calculation (TSLMTIMP)',
#   'flatlabel': 'voyage slaves numbers : Imputed number of slaves embarked for mortality calculation (TSLMTIMP)'},
#  'voyage_slaves_numbers__imp_num_men_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of men (MEN7)',
#   'flatlabel': 'voyage slaves numbers : Number of men (MEN7)'},
#  'voyage_slaves_numbers__imp_num_women_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of women (WOMEN7) ',
#   'flatlabel': 'voyage slaves numbers : Number of women (WOMEN7) '},
#  'voyage_slaves_numbers__imp_num_boy_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of boys (BOY7)',
#   'flatlabel': 'voyage slaves numbers : Number of boys (BOY7)'},
#  'voyage_slaves_numbers__imp_num_girl_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of girls (GIRL7)',
#   'flatlabel': 'voyage slaves numbers : Number of girls (GIRL7)'},
#  'voyage_slaves_numbers__imp_num_adult_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of adults (gender unspecified) (ADULT7)',
#   'flatlabel': 'voyage slaves numbers : Number of adults (gender unspecified) (ADULT7)'},
#  'voyage_slaves_numbers__imp_num_child_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of children (gender unspecified) (CHILD7)',
#   'flatlabel': 'voyage slaves numbers : Number of children (gender unspecified) (CHILD7)'},
#  'voyage_slaves_numbers__imp_num_males_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of males (age unspecified) (MALE7)',
#   'flatlabel': 'voyage slaves numbers : Number of males (age unspecified) (MALE7)'},
#  'voyage_slaves_numbers__imp_num_females_total': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Number of females (age unspecified) (FEMALE7) ',
#   'flatlabel': 'voyage slaves numbers : Number of females (age unspecified) (FEMALE7) '},
#  'voyage_slaves_numbers__total_slaves_embarked_age_gender_identified': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves embarked wi th age and gender identified (SLAVMAX1)',
#   'flatlabel': 'voyage slaves numbers : Total slaves embarked wi th age and gender identified (SLAVMAX1)'},
#  'voyage_slaves_numbers__total_slaves_by_age_gender_identified_among_landed': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age and gender among landed (SLAVMAX3)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by age and gender among landed (SLAVMAX3)'},
#  'voyage_slaves_numbers__total_slaves_by_age_gender_identified_departure_or_arrival': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Total slaves identified by age and gender at departure or arrival (SLAVMAX7)',
#   'flatlabel': 'voyage slaves numbers : Total slaves identified by age and gender at departure or arrival (SLAVMAX7)'},
#  'voyage_slaves_numbers__percentage_boys_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of boys among embarked slaves (BOYRAT1)',
#   'flatlabel': 'voyage slaves numbers : Percentage of boys among embarked slaves (BOYRAT1)'},
#  'voyage_slaves_numbers__child_ratio_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Child ratio among embarked slaves (CHILRAT1)',
#   'flatlabel': 'voyage slaves numbers : Child ratio among embarked slaves (CHILRAT1)'},
#  'voyage_slaves_numbers__percentage_girls_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of girls among embarked slaves (GIRLRAT1)',
#   'flatlabel': 'voyage slaves numbers : Percentage of girls among embarked slaves (GIRLRAT1)'},
#  'voyage_slaves_numbers__male_ratio_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Male ratio among embarked slaves (MALRAT1)',
#   'flatlabel': 'voyage slaves numbers : Male ratio among embarked slaves (MALRAT1)'},
#  'voyage_slaves_numbers__percentage_men_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of men among embarked slaves (MENRAT1)',
#   'flatlabel': 'voyage slaves numbers : Percentage of men among embarked slaves (MENRAT1)'},
#  'voyage_slaves_numbers__percentage_women_among_embarked_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of women among embarked slaves (WOMRAT1)',
#   'flatlabel': 'voyage slaves numbers : Percentage of women among embarked slaves (WOMRAT1)'},
#  'voyage_slaves_numbers__percentage_boys_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of boys among landed slaves (BOYRAT3)',
#   'flatlabel': 'voyage slaves numbers : Percentage of boys among landed slaves (BOYRAT3)'},
#  'voyage_slaves_numbers__child_ratio_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Child ratio among landed slaves (CHILRAT3)',
#   'flatlabel': 'voyage slaves numbers : Child ratio among landed slaves (CHILRAT3)'},
#  'voyage_slaves_numbers__percentage_girls_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of girls among landed slaves (GIRLRAT3)',
#   'flatlabel': 'voyage slaves numbers : Percentage of girls among landed slaves (GIRLRAT3)'},
#  'voyage_slaves_numbers__male_ratio_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Male ratio among landed slaves (MALRAT3)',
#   'flatlabel': 'voyage slaves numbers : Male ratio among landed slaves (MALRAT3)'},
#  'voyage_slaves_numbers__percentage_men_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of men among landed slaves (MENRAT3)',
#   'flatlabel': 'voyage slaves numbers : Percentage of men among landed slaves (MENRAT3)'},
#  'voyage_slaves_numbers__percentage_women_among_landed_slaves': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage of women among landed slaves (WOMRAT3)',
#   'flatlabel': 'voyage slaves numbers : Percentage of women among landed slaves (WOMRAT3)'},
#  'voyage_slaves_numbers__percentage_men': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage men on voyage (MENRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage men on voyage (MENRAT7)'},
#  'voyage_slaves_numbers__percentage_women': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage women on voyage (WOMRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage women on voyage (WOMRAT7)'},
#  'voyage_slaves_numbers__percentage_boy': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage boy on voyage (BOYRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage boy on voyage (BOYRAT7)'},
#  'voyage_slaves_numbers__percentage_girl': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage girl on voyage (GIRLRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage girl on voyage (GIRLRAT7)'},
#  'voyage_slaves_numbers__percentage_male': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage male on voyage (MALRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage male on voyage (MALRAT7)'},
#  'voyage_slaves_numbers__percentage_child': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage children on voyage (CHILRAT7)',
#   'flatlabel': 'voyage slaves numbers : Percentage children on voyage (CHILRAT7)'},
#  'voyage_slaves_numbers__percentage_adult': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage adult on voyage',
#   'flatlabel': 'voyage slaves numbers : Percentage adult on voyage'},
#  'voyage_slaves_numbers__percentage_female': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Percentage female on voyage',
#   'flatlabel': 'voyage slaves numbers : Percentage female on voyage'},
#  'voyage_slaves_numbers__imp_mortality_ratio': {'type': "<class 'rest_framework.fields.FloatField'>",
#   'label': 'Imputed mortality ratio (VYMRTRAT)',
#   'flatlabel': 'voyage slaves numbers : Imputed mortality ratio (VYMRTRAT)'},
#  'voyage_slaves_numbers__voyage': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Voyage',
#   'flatlabel': 'voyage slaves numbers : Voyage'},
#  'voyage_outcome': {'type': 'table',
#   'label': 'voyage outcome',
#   'flatlabel': 'voyage outcome'},
#  'voyage_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : ID'},
#  'voyage_outcome__outcome_owner': {'type': 'table',
#   'label': 'Owner Outcome',
#   'flatlabel': 'voyage outcome : Owner Outcome'},
#  'voyage_outcome__outcome_owner__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : Owner Outcome : ID'},
#  'voyage_outcome__outcome_owner__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Outcome label',
#   'flatlabel': 'voyage outcome : Owner Outcome : Outcome label'},
#  'voyage_outcome__outcome_owner__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome',
#   'flatlabel': 'voyage outcome : Owner Outcome : Code of outcome'},
#  'voyage_outcome__outcome_slaves': {'type': 'table',
#   'label': 'Slaves Outcome',
#   'flatlabel': 'voyage outcome : Slaves Outcome'},
#  'voyage_outcome__outcome_slaves__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : Slaves Outcome : ID'},
#  'voyage_outcome__outcome_slaves__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Outcome label',
#   'flatlabel': 'voyage outcome : Slaves Outcome : Outcome label'},
#  'voyage_outcome__outcome_slaves__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome',
#   'flatlabel': 'voyage outcome : Slaves Outcome : Code of outcome'},
#  'voyage_outcome__particular_outcome': {'type': 'table',
#   'label': 'Particular Outcome',
#   'flatlabel': 'voyage outcome : Particular Outcome'},
#  'voyage_outcome__particular_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : Particular Outcome : ID'},
#  'voyage_outcome__particular_outcome__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Outcome label',
#   'flatlabel': 'voyage outcome : Particular Outcome : Outcome label'},
#  'voyage_outcome__particular_outcome__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome',
#   'flatlabel': 'voyage outcome : Particular Outcome : Code of outcome'},
#  'voyage_outcome__resistance': {'type': 'table',
#   'label': 'Resistance',
#   'flatlabel': 'voyage outcome : Resistance'},
#  'voyage_outcome__resistance__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : Resistance : ID'},
#  'voyage_outcome__resistance__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Resistance label',
#   'flatlabel': 'voyage outcome : Resistance : Resistance label'},
#  'voyage_outcome__resistance__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of resistance',
#   'flatlabel': 'voyage outcome : Resistance : Code of resistance'},
#  'voyage_outcome__vessel_captured_outcome': {'type': 'table',
#   'label': 'Vessel Captured Outcome',
#   'flatlabel': 'voyage outcome : Vessel Captured Outcome'},
#  'voyage_outcome__vessel_captured_outcome__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage outcome : Vessel Captured Outcome : ID'},
#  'voyage_outcome__vessel_captured_outcome__name': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Outcome label',
#   'flatlabel': 'voyage outcome : Vessel Captured Outcome : Outcome label'},
#  'voyage_outcome__vessel_captured_outcome__value': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Code of outcome',
#   'flatlabel': 'voyage outcome : Vessel Captured Outcome : Code of outcome'},
#  'voyage_outcome__voyage': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Voyage',
#   'flatlabel': 'voyage outcome : Voyage'},
#  'voyage_sourceconnection': {'type': 'table',
#   'label': 'voyage sources connection',
#   'flatlabel': 'voyage sources connection'},
#  'voyage_sourceconnection__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage sources connection : ID'},
#  'voyage_sourceconnection__source': {'type': 'table',
#   'label': 'Source',
#   'flatlabel': 'voyage sources connection : Source'},
#  'voyage_sourceconnection__source__id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'ID',
#   'flatlabel': 'voyage sources connection : Source : ID'},
#  'voyage_sourceconnection__source__short_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Short reference',
#   'flatlabel': 'voyage sources connection : Source : Short reference'},
#  'voyage_sourceconnection__source__full_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Full reference',
#   'flatlabel': 'voyage sources connection : Source : Full reference'},
#  'voyage_sourceconnection__source__source_type': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Source Type',
#   'flatlabel': 'voyage sources connection : Source : Source Type'},
#  'voyage_sourceconnection__text_ref': {'type': "<class 'rest_framework.fields.CharField'>",
#   'label': 'Text reference(citation)',
#   'flatlabel': 'voyage sources connection : Text reference(citation)'},
#  'voyage_sourceconnection__voyage': {'type': "<class 'rest_framework.relations.PrimaryKeyRelatedField'>",
#   'label': 'Voyage',
#   'flatlabel': 'voyage sources connection : Voyage'},
#  'voyage_id': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Voyage ID',
#   'flatlabel': 'Voyage ID'},
#  'voyage_in_cd_rom': {'type': "<class 'rest_framework.fields.BooleanField'>",
#   'label': 'Voyage in 1999 CD-ROM?',
#   'flatlabel': 'Voyage in 1999 CD-ROM?'},
#  'last_update': {'type': "<class 'rest_framework.fields.DateTimeField'>",
#   'label': 'Last update',
#   'flatlabel': 'Last update'},
#  'dataset': {'type': "<class 'rest_framework.fields.IntegerField'>",
#   'label': 'Dataset',
#   'flatlabel': 'Dataset'}}

# %%
"""
The following three widgets are dropdown menues for the above vars. the below array constructions get the specific
labels of the data vars we are trying to use
"""

geo_drop = [drop_dict[i]['flatlabel'] for i in geo_vars]

geo_emb = widgets.Dropdown(
    options=geo_drop,
    description="Geo Vars",
    disabled=False,
)

# %%
geo_emb
# Out:
# Dropdown(description='Geo Vars', options=('Itinerary : Imputed principal place of slave purchase (MJBYPTIMP) :…

# %%
numeric_drop = [drop_dict[i]['label'] for i in numeric_vars]

numeric_emb = widgets.Dropdown(
    options=numeric_drop,
    description="Numeric Vars",
    disabled=False,
)

# %%
date_drop = [drop_dict[i]['label'] for i in date_vars]

dates_emb = widgets.Dropdown(
    options=date_drop,
    description="Dates Vars",
    disabled=False,
)
dates_emb
# Out:
# Dropdown(description='Dates Vars', options=('Year of arrival at second place of landing (DATARR37,36,38)', 'Ye…

# %%
display(dates_emb)
# Out:
# Dropdown(description='Dates Vars', index=2, options=('Year of arrival at second place of landing (DATARR37,36,…

# %%
dates_emb.value
# Out:
# 'Year that voyage began (DATEDEPB,A,C)'

# %%
url=base_url + "aggregations"
url
# Out:
# 'https://voyages3-api.crc.rice.edu/voyage/aggregations'

# %%
headers
# Out:
# {'Authorization': 'Token 3e9ed2e0fa70a1a5cb6f34eb7a30ebde208ecd8f'}

# %%
data={
    "aggregate_fields": [date_vars[date_drop.index(dates_emb.value)]]
}
data
# Out:
# {'aggregate_fields': ['voyage_dates__voyage_began_yyyy']}

# %%
date_var_name=date_vars[date_drop.index(dates_emb.value)]

# %%
r = requests.post(url, headers=headers, data=data)
date_dict = r.json()
date_dict
# Out:
# {'voyage_dates__voyage_began_yyyy': {'min': 1519, 'max': 1864}}

# %%
int(date_dict[date_var_name]['min'])
# Out:
# 1519

# %%
minyear=int(date_dict[date_var_name]['min'])
maxyear=int(date_dict[date_var_name]['max'])  # gets the max and the min year for the above chosen date_var and constructs a slider

yearslider_emb = widgets.IntRangeSlider(
    min=minyear,
    max=maxyear,
    step=1,
    description='Date Slider',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d',
)

yearslider_emb
# Out:
# IntRangeSlider(value=(1605, 1777), continuous_update=False, description='Date Slider', max=1864, min=1519)

# %%
display(numeric_emb)  # displays the dropdown menus 
display(geo_emb)
display(dates_emb)
display(yearslider_emb)
# Out:
# Dropdown(description='Numeric Vars', options=('Total slaves disembarked imputed * (SLAMIMP)', 'Total slaves em…
# Dropdown(description='Geo Vars', options=('Itinerary : Imputed principal place of slave purchase (MJBYPTIMP) :…
# Dropdown(description='Dates Vars', index=10, options=('Year of arrival at second place of landing (DATARR37,36…
# IntRangeSlider(value=(1605, 1777), continuous_update=False, description='Date Slider', max=1864, min=1519)

# %%
url = base_url + 'dataframes'

latvar=re.sub("__[^_]*?$","__latitude",geo_vars[geo_drop.index(geo_emb.value)]) 
longvar=re.sub("__[^_]*?$","__longitude",geo_vars[geo_drop.index(geo_emb.value)])

data = {
    "selected_fields": [date_vars[date_drop.index(dates_emb.value)], latvar,longvar,geo_vars[geo_drop.index(geo_emb.value)],numeric_vars[numeric_drop.index(numeric_emb.value)]],
    date_vars[date_drop.index(dates_emb.value)]: [str(yearslider_emb.value[0]), str(yearslider_emb.value[1])]
}
r = requests.post(url, headers=headers, data=data)
j = r.text

# %%
df = pd.read_json(j)
df = df.dropna()
df = df.sort_values(by=[date_vars[date_drop.index(dates_emb.value)]])
df
# Out:
#       voyage_dates__voyage_began_yyyy  \
# 9089                             1605
# 9088                             1605
# 5434                             1606
# 5590                             1606
# 5766                             1606
# ...                               ...
# 7769                             1777
# 7771                             1777
# 7772                             1777
# 8103                             1777
# 6955                             1777
#
#       voyage_itinerary__imp_principal_place_of_slave_purchase__latitude  \
# 9089                                           0.054033
# 9088                                           0.054033
# 5434                                          -8.838330
# 5590                                          16.101800
# 5766                                           0.054033
# ...                                                 ...
# 7769                                          -8.838330
# 7771                                           0.000000
# 7772                                           0.000000
# 8103                                           0.000000
# 6955                                           4.433330
#
#       voyage_itinerary__imp_principal_place_of_slave_purchase__longitude  \
# 9089                                           9.343897
# 9088                                           9.343897
# 5434                                          13.234440
# 5590                                         -22.938750
# 5766                                           9.343897
# ...                                                 ...
# 7769                                          13.234440
# 7771                                           0.000000
# 7772                                           0.000000
# 8103                                           0.000000
# 6955                                           7.166670
#
#      voyage_itinerary__imp_principal_place_of_slave_purchase__place  \
# 9089                          Africa., port unspecified
# 9088                          Africa., port unspecified
# 5434  West Central Africa and St. Helena, port unspe...
# 5590                                 Cape Verde Islands
# 5766                          Africa., port unspecified
# ...                                                 ...
# 7769  West Central Africa and St. Helena, port unspe...
# 7771                         Gold Coast, Fr. definition
# 7772                         Gold Coast, Fr. definition
# 8103                         Gold Coast, Fr. definition
# 6955                                              Bonny
#
#       voyage_slaves_numbers__imp_total_num_slaves_disembarked
# 9089                                              321.0
# 9088                                              268.0
# 5434                                              124.0
# 5590                                              277.0
# 5766                                              287.0
# ...                                                 ...
# 7769                                              351.0
# 7771                                              719.0
# 7772                                              170.0
# 8103                                              266.0
# 6955                                              407.0
#
# [14135 rows x 5 columns]

# %%
df2 = df.groupby([latvar, # combines data for duplicate geo and date vars. 
                  longvar,
                  geo_vars[geo_drop.index(geo_emb.value)], 
                  date_vars[date_drop.index(dates_emb.value)]], as_index=False).sum()

df2 = df2.rename({latvar: 'Latitude',  # rename the var names to the label names to be more descriptive
                  longvar: 'Longitude', 
                  geo_vars[geo_drop.index(geo_emb.value)]: geo_emb.value,
                  numeric_vars[numeric_drop.index(numeric_emb.value)] : numeric_emb.value,
                  date_vars[date_drop.index(dates_emb.value)]: dates_emb.value, 
                 }, axis=1)

df2 = df2.assign(normalized_sizes = np.log(df2[numeric_emb.value])) # normalize sizes to accommodate various data points

df2 = df2.sort_values(by=dates_emb.value) 
fig = px.scatter_geo(df2, lon = 'Longitude', # constructs the bubble map 
                     lat = 'Latitude',
                     title = '%s - by - %s' %(numeric_emb.value,geo_emb.value),
                     hover_name = geo_emb.value,
                     animation_frame = dates_emb.value,
                     size = 'normalized_sizes',
                     hover_data = [numeric_emb.value])
fig.show()
# Out:
# <div>                            <div id="5347ee56-3fb1-401e-944d-c8f03895c0e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5347ee56-3fb1-401e-944d-c8f03895c0e2")) {                    Plotly.newPlot(                        "5347ee56-3fb1-401e-944d-c8f03895c0e2",                        [{"customdata":[[589.0]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Year that voyage began (DATEDEPB,A,C)=1605<br>normalized_sizes=%{marker.size}<br>Latitude=%{lat}<br>Longitude=%{lon}<br>Total slaves disembarked imputed * (SLAMIMP)=%{customdata[0]}<extra></extra>","hovertext":["Africa., port unspecified"],"lat":[0.054033],"legendgroup":"","lon":[9.343897],"marker":{"color":"#636efa","size":[6.3784261836515865],"sizemode":"area","sizeref":0.02462284239446512,"symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"p ...

# %%
fig = px.bar(df2, x=dates_emb.value, # constructs the stacked bar graph
             y=numeric_emb.value, color=geo_emb.value
             )
fig.update_xaxes(dtick=int((maxyear-minyear)/10)) # updates the interval between each tick on the x-axis. 
fig.show()
# Out:
# <div>                            <div id="c078440d-0e42-44ba-9305-ceefcc1b4060" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c078440d-0e42-44ba-9305-ceefcc1b4060")) {                    Plotly.newPlot(                        "c078440d-0e42-44ba-9305-ceefcc1b4060",                        [{"alignmentgroup":"True","hovertemplate":"Itinerary : Imputed principal place of slave purchase (MJBYPTIMP) : Place=Africa., port unspecified<br>Year that voyage began (DATEDEPB,A,C)=%{x}<br>Total slaves disembarked imputed * (SLAMIMP)=%{y}<extra></extra>","legendgroup":"Africa., port unspecified","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa., port unspecified","offsetgroup":"Africa., port unspecified","orientation":"v","showlegend":true,"textposition":"auto","x":[1605,1606,1608,1609,1610,1611,1623,1624,1625,1626,1632,1633,1634,1635,1639,1642,1643,1644,1645,1646,1649,1650,1652,1653,1654,1655,1656,1657,1658,1659,1660,1662,1663,1664,1665,1666,1667,1668,1669,1670,1671,1673,1674,1675,1676,1677,1678,1679,1681,1682,1683,1684,1685,1686,1687,1688,1690,1691,1692,1693,1694,1695,1696,1697,1698,1699,1700,1701,1702,1703,1704,1705,1706,1707,1708,1709,1710,1711,1712,1713,1714,1715,1716,1717,1718,1719,1720,1721,1722,1723,1724,1725,1726,1727,1728,1729,1730,1731,1732,1733,1734,1735,1736,1737,1738,1739,1740,1741,1742,1743,1744,1745,1746,1747,1748,1749,1750,1751,1752,1753,1754,1755,1756,1757,1758,1759,1760,1761,1762,1763,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777],"xaxis":"x","y":[589.0,1148.0,3731.0,5916.0,3731.0,574.0,287.0,287.0,574.0,287.0,287.0,287.0,287.0,287.0,287.0,235.0,264.0,209.0,1008.0,742.0,126.0,414.0,806.0,234.0,2049.0,485.0,1058.0,491.0,394.0,1294.0,316.0,1203.0,1105.0,572.0,689.0,444.0,813.0,1322.0,1332.0,285.0,818.0,445.0,574.0,885.0,1012.0,826.0,241.0,1775.0,1185.0,1439.0,241.0,746.0,942.0,1338.0,1329.0,923.0,1499.0,2443.0,2089.0,2957.0,1251.0,616.0,1754.0,598.0,7510.0,10424.0,18942.0,13627.0,5937.0,3995.0,6014.0,2177.0,2766.0,5189.0,3766.0,3766.0,4374.0,6683.0,4290.0,5928.0,5200.0,4811.0,8496.0,9818.0,7438.0,4238.0,4555.0,4867.0,4847.0,5623.0,8846.0,11397.0,10061.0,11504.0,14908.0,9255.0,9466.0,12659.0,11753.0,9977.0,9842.0,13541.0,14062.0,16360.0,16488.0,12418.0,12474.0,14165.0,8996.0,10466.0,4380.0,8206.0,9438.0,9081.0,7206.0,7521.0,2818.0,4381.0,5305.0,7069.0,6128.0,6579.0,3269.0,2230.0,2111.0,3711.0,3622.0,5996.0,2769.0,6450.0,5676.0,7211.0,5109.0,4234.0,5468.0,6667.0,8598.0,8196.0,9021.0,6750.0,5667.0,5314.0,2827.0,4937.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Itinerary : Imputed principal place of slave purchase (MJBYPTIMP) : Place=West Central Africa and St. Helena, port unspecified<br>Year that voyage began (DATEDEPB,A,C)=%{x}<br>Total slaves disembarked imputed * (SLAMIMP)=%{y}<extra></extra>","legendgroup":"West Central Africa and St. Helena, port unspecified","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"West Central Africa and St. Helena, port unspecified","offsetgroup":"West Central Africa and St. Helena, port unspecified","orientation":"v","showlegend":true,"textposition":"auto","x":[1606,1607,1608,1609,1610,1611,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1647,1649,1650,1651,1655,1657,1658,1659,1660,1662,1663,1664,1666,1668,1669,1670,1671,1676,1677,1678,1679,1680,1681,1682,1683,1684,1685,1686,1687,1688,1689,1690,1691,1692,1693,1694,1695,1696,1698,1699,1700,1701,1702,1703,1705,1706,1707,1708,1709,1710,1711,1712,1714,1715,1716,1717,1718,1719,1720,1721,1722,1723,1724,1725,1726,1727,1729,1730,1731,1732,1733,1734,1735,1736,1737,1738,1739,1740,1741,1742,1743,1744,1745,1747,1748,1749,1750,1751,1752,1753,1754,1755,1756,1757,1758 ...
